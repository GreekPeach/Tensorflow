# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from keras.datasets import fashion_mnist

# %%
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()

# %%
item_dic = {0:"T-shirt/top",
1:"Trouser",
2:"Pullover",
3:"Dress",
4:"Coat",
5:"Sandal",
6:"Shirt",
7:"Sneaker",
8:"Bag",
9:"Ankle boot"}

# %%
plt.style.use("dark_background")
plt.imshow(train_data[7])

# %%
train_data.shape, train_labels.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
# mnist_1= tf.keras.Sequential([
#     tf.keras.layers.Flatten(input_shape=(28,28)),
#     tf.keras.layers.Dense(10, activation = "relu"),
#     tf.keras.layers.Dense(100, activation="relu"),
#     tf.keras.layers.Dense(10, activation="softmax")
# ])

# mnist_1.compile(loss=tf.keras.losses.sparse_categorical_crossentropy,
#                 metrics = ["accuracy"],
#                optimizer=tf.keras.optimizers.Adam())

# hist_1 = mnist_1.fit(train_data,
#                      train_labels,
#                      epochs = 30,
#                     validation_data = (test_data, test_labels))

# mnist_1.summary()

# %% [markdown]
# ---------------------------------------------------

# %%
# Normalization
train_data_norm = train_data/255
test_data_norm = test_data/255
train_data_norm.min(), train_data_norm.max()
# Out:
# (0.0, 1.0)

# %%
# mnist_2 = tf.keras.Sequential([
#     tf.keras.layers.Flatten(input_shape=(28,28)),
#     tf.keras.layers.Dense(10, activation = "relu"),
#     tf.keras.layers.Dense(100, activation = "relu"),
#     tf.keras.layers.Dense(10, activation = "softmax")
# ])

# mnist_2.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
#                optimizer=tf.keras.optimizers.Adam(),
#                metrics="accuracy")

# hist_2 = mnist_2.fit(x=train_data_norm,
#                   y=train_labels,
#                   epochs = 30,
#                   validation_data=(test_data_norm, test_labels))

# %%
# pd.DataFrame(hist_1.history).plot()

# %%
# pd.DataFrame(hist_2.history).plot()

# %%
mnist_3 = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = (28,28)),
    tf.keras.layers.Dense(10, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "relu"),
    tf.keras.layers.Dense(10, activation = "softmax")
])

mnist_3.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
               optimizer = tf.keras.optimizers.Adam(),
               metrics = "accuracy")

hist_3 = mnist_3.fit(train_data_norm,
           train_labels,
           epochs=40,
            validation_data=(test_data_norm, test_labels))
# Out:
# Epoch 1/40
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7651 - accuracy: 0.7513 - val_loss: 0.5229 - val_accuracy: 0.8201
# Epoch 2/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4669 - accuracy: 0.8371 - val_loss: 0.4764 - val_accuracy: 0.8347
# Epoch 3/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4333 - accuracy: 0.8499 - val_loss: 0.4725 - val_accuracy: 0.8346
# Epoch 4/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4175 - accuracy: 0.8541 - val_loss: 0.4623 - val_accuracy: 0.8382
# Epoch 5/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4065 - accuracy: 0.8569 - val_loss: 0.4440 - val_accuracy: 0.8456
# Epoch 6/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3981 - accuracy: 0.8603 - val_loss: 0.4412 - val_accuracy: 0.8436
# Epoch 7/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3921 - accuracy: 0.8622 - val_loss: 0.4469 - val_accuracy: 0.8425
# Epoch 8/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3843 - accuracy: 0.8643 - val_loss: 0.4253 - val_accuracy: 0.8512
# Epoch 9/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3790 - accuracy: 0.8644 - val_loss: 0.4443 - val_accuracy: 0.8464
# Epoch 10/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3755 - accuracy: 0.8669 - val_loss: 0.4270 - val_accuracy: 0.8490
# Epoch 11/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3724 - accuracy: 0.8674 - val_loss: 0.4242 - val_accuracy: 0.8499
# Epoch 12/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3681 - accuracy: 0.8691 - val_loss: 0.4403 - val_accuracy: 0.8495
# Epoch 13/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3646 - accuracy: 0.8699 - val_loss: 0.4364 - val_accuracy: 0.8427
# Epoch 14/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3622 - accuracy: 0.8702 - val_loss: 0.4282 - val_accuracy: 0.8477
# Epoch 15/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3603 - accuracy: 0.8722 - val_loss: 0.4159 - val_accuracy: 0.8533
# Epoch 16/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3582 - accuracy: 0.8731 - val_loss: 0.4324 - val_accuracy: 0.8489
# Epoch 17/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3546 - accuracy: 0.8736 - val_loss: 0.4180 - val_accuracy: 0.8508
# Epoch 18/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3540 - accuracy: 0.8743 - val_loss: 0.4248 - val_accuracy: 0.8503
# Epoch 19/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3503 - accuracy: 0.8751 - val_loss: 0.4234 - val_accuracy: 0.8510
# Epoch 20/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3504 - accuracy: 0.8737 - val_loss: 0.4212 - val_accuracy: 0.8505
# Epoch 21/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3475 - accuracy: 0.8757 - val_loss: 0.4294 - val_accuracy: 0.8510
# Epoch 22/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3462 - accuracy: 0.8754 - val_loss: 0.4373 - val_accuracy: 0.8468
# Epoch 23/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3462 - accuracy: 0.8770 - val_loss: 0.4183 - val_accuracy: 0.8534
# Epoch 24/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3426 - accuracy: 0.8776 - val_loss: 0.4230 - val_accuracy: 0.8530
# Epoch 25/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3418 - accuracy: 0.8771 - val_loss: 0.4279 - val_accuracy: 0.8519
# Epoch 26/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3408 - accuracy: 0.8775 - val_loss: 0.4167 - val_accuracy: 0.8539
# Epoch 27/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3401 - accuracy: 0.8793 - val_loss: 0.4240 - val_accuracy: 0.8536
# Epoch 28/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3385 - accuracy: 0.8781 - val_loss: 0.4383 - val_accuracy: 0.8485
# Epoch 29/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3384 - accuracy: 0.8785 - val_loss: 0.4303 - val_accuracy: 0.8501
# Epoch 30/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3369 - accuracy: 0.8794 - val_loss: 0.4336 - val_accuracy: 0.8474
# Epoch 31/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3358 - accuracy: 0.8796 - val_loss: 0.4261 - val_accuracy: 0.8518
# Epoch 32/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3346 - accuracy: 0.8799 - val_loss: 0.4306 - val_accuracy: 0.8515
# Epoch 33/40
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3332 - accuracy: 0.8801 - val_loss: 0.4275 - val_accuracy: 0.8531
# Epoch 34/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3333 - accuracy: 0.8804 - val_loss: 0.4385 - val_accuracy: 0.8496
# Epoch 35/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3315 - accuracy: 0.8804 - val_loss: 0.4239 - val_accuracy: 0.8556
# Epoch 36/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3310 - accuracy: 0.8808 - val_loss: 0.4234 - val_accuracy: 0.8517
# Epoch 37/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3293 - accuracy: 0.8820 - val_loss: 0.4278 - val_accuracy: 0.8503
# Epoch 38/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3291 - accuracy: 0.8822 - val_loss: 0.4288 - val_accuracy: 0.8531
# Epoch 39/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3279 - accuracy: 0.8824 - val_loss: 0.4309 - val_accuracy: 0.8516
# Epoch 40/40
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3277 - accuracy: 0.8823 - val_loss: 0.4551 - val_accuracy: 0.8434

# %%
pd.DataFrame(hist_3.history).plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_true = test_labels
y_pred = np.argmax(mnist_3.predict(test_data_norm), axis=1)
cr = classification_report(y_true, y_pred)
print(cr)
# Out:
# 313/313 [==============================] - 0s 798us/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79      1000
#            1       0.96      0.97      0.96      1000
#            2       0.68      0.80      0.74      1000
#            3       0.74      0.91      0.82      1000
#            4       0.73      0.78      0.76      1000
#            5       0.96      0.92      0.94      1000
#            6       0.74      0.42      0.54      1000
#            7       0.92      0.96      0.94      1000
#            8       0.94      0.95      0.95      1000
#            9       0.94      0.95      0.95      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
cm = confusion_matrix(y_true=y_true,
                     y_pred=y_pred)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot = True, cmap="Blues")
# Out:
# <Axes: >

# %%
for i in range(0,9):
    print(f"{i} {item_dic[i]}")
# Out:
# 0 T-shirt/top
# 1 Trouser
# 2 Pullover
# 3 Dress
# 4 Coat
# 5 Sandal
# 6 Shirt
# 7 Sneaker
# 8 Bag

# %%
mnist_3.layers[1]

# %%
weights, biases = mnist_3.layers[1].get_weights()
weights, biases
# Out:
# (array([[ 0.08104541,  0.42424026, -0.44471315, ..., -0.05131631,
#          -0.04327765,  0.74434817],
#         [ 0.05203841, -0.5117639 ,  0.9080097 , ..., -0.05791461,
#           1.197095  ,  1.2435246 ],
#         [ 0.33077446, -1.8028451 ,  1.142911  , ...,  0.00486799,
#           0.49623483,  1.1429069 ],
#         ...,
#         [ 0.50753933,  0.14892457,  0.33554694, ..., -0.04304334,
#          -0.14374833,  0.18611957],
#         [ 0.0754302 , -0.12172423,  0.1252339 , ..., -0.04994414,
#           1.2902664 ,  1.5106044 ],
#         [-0.63627887, -0.13721107,  0.6961439 , ..., -0.0268141 ,
#           0.5706484 ,  1.0056393 ]], dtype=float32),
#  array([ 1.7151675 , -0.19162035,  0.7786654 ,  0.82019   ,  0.01204212,
#          0.12637138,  0.3771633 , -0.02201041,  0.7710796 ,  0.30879202],
#        dtype=float32))

# %%
mnist_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 8,070
# Trainable params: 8,070
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(mnist_3,show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
